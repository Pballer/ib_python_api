# %%
import sqlite3
import pandas as pd
import plotly
from plotly import figure_factory as FF
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
try:
    db_conn = sqlite3.connect('./db/ib_api.db')
except Exception as e:
    print(e)
    raise e

# %%
query = """select datetime(a.date, 'localtime') insert_date, b.symbol, a.ticktype, a.value
    from tick_market_data a join tickers b 
    on a.tickerid = b.requestid
    where b.requestid = 1
    and a.date BETWEEN '2019-08-15'  and '2019-08-16'
    and a.ticktype = 'DELAYED_ASK'
    """

# %%
ticker_data = pd.read_sql_query(sql=query, con=db_conn)

# %%
ticker_data.insert_date = pd.to_datetime(ticker_data.insert_date)

# %%
ticker_data.set_index('insert_date', inplace=True)

# %%
ohlc_5mins = ticker_data['value'].resample('5Min').ohlc()

# %%
ohlc_5mins.head()
# Out:
#                       open   high    low  close
# insert_date
# 2019-08-15 12:25:00  36.42  36.48  36.33  36.34
# 2019-08-15 12:30:00  36.33  36.58  36.32  36.58
# 2019-08-15 12:35:00  36.59  36.65  36.53  36.65
# 2019-08-15 12:40:00  36.64  36.64  36.44  36.58
# 2019-08-15 12:45:00  36.54  36.62  36.50  36.55

# %%
fig = FF.create_ohlc(ohlc_5mins.open, ohlc_5mins.high, ohlc_5mins.low, ohlc_5mins.close, dates=ohlc_5mins.index)

# %%
plotly.offline.iplot(fig, filename='sample_ohlc')
# Out:
# <div id="7cf01dae-12bf-40a5-9577-cded5f4715f4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '7cf01dae-12bf-40a5-9577-cded5f4715f4',
#             [{"line": {"color": "#3D9970", "width": 1}, "mode": "lines", "name": "Increasing", "showlegend": false, "text": ["Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", "", "Open", "Open", "High", "Low", "Close", "Close", ""], "x": ["2019-08-15 12:29:00", "2019-08-15 12:30:00", "2019-08-15 12:30:00", "2019-08-15 12:30:00", "2019-08-15 12:30:00", "2019-08-15 12:31:00", null, "2019-08-15 12:34:00", "2019-08-15 12:35:00", "2019-08-15 12:35:00", "2019-08-15 12:35:00", "2019-08-15 12:35:00", "2019-08-15 12:36:00", null, "2019-08-15 12:44:00", "2019-08-15 12:45:00", "2019-08-15 12:45:00", "2019-08-15 12:45:00", "2019-08-15 12:45:00", "2019-08-15 12:46:00", null, "2019-08-15 13:04:00", "2019-08-15 13:05:00", "2019-08-15 13:05:00", "2019-08-15 13:05:00", "2019-08-15 13:05:00", "2019-08-15 13:06:00", null, "2019-08-15 13:29:00", "2019-08-15 13:30:00", "2019-08-15 13:30:00", "2019-08-15 13:30:00", "2019-08-15 13:30:00", "2019-08-15 13:31:00", null, "2019-08-15 13:34:00", "2019-08-15 13:35:00", "2019-08-15 13:35:00", "2019-08-15 13:35:00", "2019-08-15 13:35:00", "2019-08-15 13:36:00", null, "2019-08-15 13:39:00", "2019-08-15 13:40:00", "2019-08-15 13:40:00", "2019-08-15 13:40:00", "2019-08-15 13:40:00", "2019-08-15 13:41:00", null, "2019-08-15 13:44:00", "2019-08-15 13:45:00", "2019-08-15 13:45:00", "2019-08-15 13:45:00", "2019-08-15 13:45:00", "2019-08-15 13:46:00", null, "2019-08-15 13:49:00", "2019-08-15 13:50:00", "2019-08-15 13:50:00", "2019-08-15 13:50:00", "2019-08-15 13:50:00", "2019-08-15 13:51:00", null, "2019-08-15 13:59:00", "2019-08-15 14:00:00", "2019-08-15 14:00:00", "2019-08-15 14:00:00", "2019-08-15 14:00:00", "2019-08-15 14:01:00", null, "2019-08-15 14:14:00", "2019-08-15 14:15:00", "2019-08-15 14:15:00", "2019-08-15 14:15:00", "2019-08-15 14:15:00", "2019-08-15 14:16:00", null, "2019-08-15 14:34:00", "2019-08-15 14:35:00", "2019-08-15 14:35:00", "2019-08-15 14:35:00", "2019-08-15 14:35:00", "2019-08-15 14:36:00", null, "2019-08-15 14:39:00", "2019-08-15 14:40:00", "2019-08-15 14:40:00", "2019-08-15 14:40:00", "2019-08-15 14:40:00", "2019-08-15 14:41:00", null, "2019-08-15 14:44:00", "2019-08-15 14:45:00", "2019-08-15 14:45:00", "2019-08-15 14:45:00", "2019-08-15 14:45:00", "2019-08-15 14:46:00", null, "2019-08-15 14:49:00", "2019-08-15 14:50:00", "2019-08-15 14:50:00", "2019-08-15 14:50:00", "2019-08-15 14:50:00", "2019-08-15 14:51:00", null, "2019-08-15 15:04:00", "2019-08-15 15:05:00", "2019-08-15 15:05:00", "2019-08-15 15:05:00", "2019-08-15 15:05:00", "20 ...
